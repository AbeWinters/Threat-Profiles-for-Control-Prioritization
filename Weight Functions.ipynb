# %% [markdown]
# # Experiment with weight functions

# %% [markdown]
# ## Graphs
# Graphs for
# - 1/x
# - 1/x^2
# - 1/sqrt(x)
# - 1/log(x)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,20,1)

y1 = 1/x 
y2 = 1/np.exp2(x)
y3 = 1/np.sqrt(x)
y4 = 1/np.log(x)
K = 2
w = K*np.exp(-x)

plt.plot(x,w, label="2*e^x")
plt.plot(x,y1,label="1/x")
plt.plot(x,y2,label="1/(2^x)")
plt.plot(x,y3, label="1/sqrt(x)")
plt.plot(x,y4, label="1/log(x)")
plt.legend()
plt.show()
# Out:
# C:\Users\a.winters\AppData\Local\Temp\ipykernel_22032\1608783064.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   y4 = 1/np.log(x)

# %% [markdown]
# Before choosing an inverse weighting function for the operations and the newness, requirements need to be set.
# - The function should not deteriorate too quickly
# - Since the buzz will be multiplied to the weighted operation count, it should be taken into account that in can decrease the result rather fast.
#
# The importance of newness and recent operations, or the lack of importance of older operations, should be defined. For this, an experiment is set up to answer the following question: How active are APTs generally after they are first seen?
#
# Based on the graph, I decide to pursue the 1/x for the operations weighing since it prioritizes recent operations more compared to the inverse square root.
# For the buzz the inverse square root is chosen, since it does not diminish the number of operations too quickly.

# %%
import pandas as pd
pd.DataFrame(list(zip(x,y1,y2,y3,y4,w)),columns=['x','1/x','1/(2^x)','1/sqrt(x)','1/log(x)','w'])
# Out:
#      x       1/x   1/(2^x)  1/sqrt(x)  1/log(x)             w
# 0    1  1.000000  0.500000   1.000000       inf  7.357589e-01
# 1    2  0.500000  0.250000   0.707107  1.442695  2.706706e-01
# 2    3  0.333333  0.125000   0.577350  0.910239  9.957414e-02
# 3    4  0.250000  0.062500   0.500000  0.721348  3.663128e-02
# 4    5  0.200000  0.031250   0.447214  0.621335  1.347589e-02
# 5    6  0.166667  0.015625   0.408248  0.558111  4.957504e-03
# 6    7  0.142857  0.007812   0.377964  0.513898  1.823764e-03
# 7    8  0.125000  0.003906   0.353553  0.480898  6.709253e-04
# 8    9  0.111111  0.001953   0.333333  0.455120  2.468196e-04
# 9   10  0.100000  0.000977   0.316228  0.434294  9.079986e-05
# 10  11  0.090909  0.000488   0.301511  0.417032  3.340340e-05
# 11  12  0.083333  0.000244   0.288675  0.402430  1.228842e-05
# 12  13  0.076923  0.000122   0.277350  0.389871  4.520659e-06
# 13  14  0.071429  0.000061   0.267261  0.378923  1.663057e-06
# 14  15  0.066667  0.000031   0.258199  0.369269  6.118046e-07
# 15  16  0.062500  0.000015   0.250000  0.360674  2.250703e-07
# 16  17  0.058824  0.000008   0.242536  0.352956  8.279875e-08
# 17  18  0.055556  0.000004   0.235702  0.345976  3.045996e-08
# 18  19  0.052632  0.000002   0.229416  0.339623  1.120559e-08
