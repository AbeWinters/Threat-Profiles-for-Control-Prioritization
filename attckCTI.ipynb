# %%
from attackcti import attack_client
from pandas import json_normalize
import sys

def get_attck_dataframe(matrix = 'enterprise'):
    if  (matrix.lower() == 'enterprise'):
        # Instantiating attack_client class
        lift = attack_client()
        # Getting techniques for windows platform - enterprise matrix
        attck = lift.get_enterprise_techniques(stix_format = False)
        # Generating a dataframe with information collected
        attck = json_normalize(attck)
        return attck
    else:
        sys.exit('ERROR: Only Enterprise available!!')

# Get enterprise techniques
attck = get_attck_dataframe()
print('Number of TTPs:',len(attck))

attck.head()
# Out:
# [taxii2client.v20] [WARNING ] [2023-04-07 14:05:19,463] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2023-04-07 14:05:19,479] TAXII Server Response with different amount of objects! Setting per_request=737
# Number of TTPs: 594
#                                    kill_chain_phases  \
# 0  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 1  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 2  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 3  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 4  [{'kill_chain_name': 'mitre-attack', 'phase_na...
#
#                                  external_references  \
# 0  [{'source_name': 'mitre-attack', 'url': 'https...
# 1  [{'source_name': 'mitre-attack', 'url': 'https...
# 2  [{'source_name': 'mitre-attack', 'url': 'https...
# 3  [{'source_name': 'mitre-attack', 'url': 'https...
# 4  [{'source_name': 'mitre-attack', 'url': 'https...
#
#   x_mitre_attack_spec_version x_mitre_deprecated      x_mitre_domains  \
# 0                       2.1.0              False  [enterprise-attack]
# 1                       3.0.0              False  [enterprise-attack]
# 2                       2.1.0              False  [enterprise-attack]
# 3                       2.1.0              False  [enterprise-attack]
# 4                       2.1.0              False  [enterprise-attack]
#
#                           x_mitre_modified_by_ref x_mitre_version  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
#
#              type                                                 id  \
# 0  attack-pattern  attack-pattern--005cc321-08ce-4d17-b1ea-cb5275...
# 1  attack-pattern  attack-pattern--e5d550f3-2202-4634-85f2-4a200a...
# 2  attack-pattern  attack-pattern--0533ab23-3f7d-463f-9bd8-634d27...
# 3  attack-pattern  attack-pattern--2f41939b-54c3-41d6-8f8b-35f1ec...
# 4  attack-pattern  attack-pattern--54ca26f3-c172-4231-93e5-ccebca...
#
#                                    created_by_ref  ... is_subtechnique  \
# 0  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  ...            True
# 1  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  ...            True
# 2  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  ...            True
# 3  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  ...            True
# 4  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  ...            True
#
#                                             platform system_requirements  \
# 0                            [Linux, macOS, Windows]                 NaN
# 1                                              [PRE]                 NaN
# 2                            [macOS, Windows, Linux]              [User]
# 3                            [macOS, Linux, Windows]                 NaN
# 4  [Windows, Azure AD, SaaS, Google Workspace, Of...                 NaN
#
#   effective_permissions permissions_required defense_bypassed remote_support  \
# 0                   NaN                  NaN              NaN            NaN
# 1                   NaN                  NaN              NaN            NaN
# 2                   NaN                  NaN              NaN            NaN
# 3                   NaN                  NaN              NaN            NaN
# 4                   NaN                  NaN              NaN            NaN
#
#   capec_id capec_url impact_type
# 0      NaN       NaN         NaN
# 1      NaN       NaN         NaN
# 2      NaN       NaN         NaN
# 3      NaN       NaN         NaN
# 4      NaN       NaN         NaN
#
# [5 rows x 32 columns]

# %%
mitre_columns = ['technique_id','technique','kill_chain_phases','id','tactic','technique_detection','impact_type']
attck[mitre_columns]
# Out:
#     technique_id                 technique  \
# 0      T1205.002            Socket Filters
# 1      T1608.006             SEO Poisoning
# 2      T1027.009         Embedded Payloads
# 3      T1027.008         Stripped Payloads
# 4      T1556.007           Hybrid Identity
# ..           ...                       ...
# 589        T1007  System Service Discovery
# 590        T1006      Direct Volume Access
# 591        T1005    Data from Local System
# 592        T1003     OS Credential Dumping
# 593        T1001          Data Obfuscation
#
#                                      kill_chain_phases  \
# 0    [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 1    [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 2    [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 3    [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 4    [{'kill_chain_name': 'mitre-attack', 'phase_na...
# ..                                                 ...
# 589  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 590  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 591  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 592  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 593  [{'kill_chain_name': 'mitre-attack', 'phase_na...
#
#                                                     id  \
# 0    attack-pattern--005cc321-08ce-4d17-b1ea-cb5275...
# 1    attack-pattern--e5d550f3-2202-4634-85f2-4a200a...
# 2    attack-pattern--0533ab23-3f7d-463f-9bd8-634d27...
# 3    attack-pattern--2f41939b-54c3-41d6-8f8b-35f1ec...
# 4    attack-pattern--54ca26f3-c172-4231-93e5-ccebca...
# ..                                                 ...
# 589  attack-pattern--322bad5a-1c49-4d23-ab79-76d641...
# 590  attack-pattern--0c8ab3eb-df48-4b9c-ace7-beacaa...
# 591  attack-pattern--3c4a2599-71ee-4405-ba1e-0e2841...
# 592  attack-pattern--0a3ead4e-6d47-4ccb-854c-a6a4f9...
# 593  attack-pattern--ad255bfe-a9e6-4b52-a258-8d3462...
#
#                                                 tactic  \
# 0    [defense-evasion, persistence, command-and-con...
# 1                               [resource-development]
# 2                                    [defense-evasion]
# 3                                    [defense-evasion]
# 4    [credential-access, defense-evasion, persistence]
# ..                                                 ...
# 589                                        [discovery]
# 590                                  [defense-evasion]
# 591                                       [collection]
# 592                                [credential-access]
# 593                              [command-and-control]
#
#                                    technique_detection impact_type
# 0    Identify running processes with raw sockets. E...         NaN
# 1                                                              NaN
# 2                                                              NaN
# 3                                                              NaN
# 4                                                              NaN
# ..                                                 ...         ...
# 589  System and network discovery techniques normal...         NaN
# 590  Monitor handle opens on drive volumes that are...         NaN
# 591  Monitor processes and command-line arguments f...         NaN
# 592  ### Windows\nMonitor for unexpected processes ...         NaN
# 593  Analyze network data for uncommon data flows (...         NaN
#
# [594 rows x 7 columns]

# %%
attck['impact_type'].value_counts()
# Out:
# [Availability]    19
# [Integrity]        7
# Name: impact_type, dtype: int64

# %%
# These functions are copied from: https://github.com/Cyb3rPandaH/attack-datasources/blob/main/docs/scripts/notebook_functions.py
# Function to import ATT&CK content as a list of dictionaries

def get_mitigation(matrix = 'enterprise'):
    if  (matrix.lower() == 'enterprise'):
        # Instantiating attack_client class
        lift = attack_client()
        # Getting techniques for windows platform - enterprise matrix
        attck = lift.get_enterprise_mitigations(stix_format = False)
        # Removing revoked techniques
        # attck = lift.remove_revoked(attck)
        return attck
    else:
        sys.exit('ERROR: Only Enterprise available!!')

mitigations = json_normalize(get_mitigation())
print(mitigations.columns)
mitigations
# Out:
# [taxii2client.v20] [WARNING ] [2023-04-07 14:05:28,617] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2023-04-07 14:05:28,673] TAXII Server Response with different amount of objects! Setting per_request=267
# Index(['external_references', 'object_marking_refs', 'x_mitre_domains',
#        'x_mitre_modified_by_ref', 'x_mitre_version', 'type', 'id',
#        'created_by_ref', 'created', 'modified', 'mitigation',
#        'mitigation_description', 'url', 'matrix', 'mitigation_id',
#        'x_mitre_attack_spec_version', 'x_mitre_deprecated'],
#       dtype='object')
#                                    external_references  \
# 0    [{'source_name': 'mitre-attack', 'url': 'https...
# 1    [{'source_name': 'mitre-attack', 'url': 'https...
# 2    [{'source_name': 'mitre-attack', 'url': 'https...
# 3    [{'source_name': 'mitre-attack', 'url': 'https...
# 4    [{'source_name': 'mitre-attack', 'url': 'https...
# ..                                                 ...
# 262  [{'source_name': 'mitre-attack', 'url': 'https...
# 263  [{'source_name': 'mitre-attack', 'url': 'https...
# 264  [{'source_name': 'mitre-attack', 'url': 'https...
# 265  [{'source_name': 'mitre-attack', 'url': 'https...
# 266  [{'source_name': 'mitre-attack', 'url': 'https...
#
#                                    object_marking_refs  \
# 0    [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 1    [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 2    [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 3    [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 4    [marking-definition--fa42a846-8d90-4e51-bc29-7...
# ..                                                 ...
# 262  [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 263  [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 264  [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 265  [marking-definition--fa42a846-8d90-4e51-bc29-7...
# 266  [marking-definition--fa42a846-8d90-4e51-bc29-7...
#
#                         x_mitre_domains  \
# 0                   [enterprise-attack]
# 1                   [enterprise-attack]
# 2                   [enterprise-attack]
# 3                   [enterprise-attack]
# 4                   [enterprise-attack]
# ..                                  ...
# 262                 [enterprise-attack]
# 263                 [enterprise-attack]
# 264                 [enterprise-attack]
# 265                 [enterprise-attack]
# 266  [enterprise-attack, mobile-attack]
#
#                             x_mitre_modified_by_ref x_mitre_version  \
# 0    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 1    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 2    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 3    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.1
# 4    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.1
# ..                                              ...             ...
# 262  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 263  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 264  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 265  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
# 266  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5             1.0
#
#                  type                                                 id  \
# 0    course-of-action  course-of-action--65401701-019d-44ff-b223-08d5...
# 1    course-of-action  course-of-action--78bb71be-92b4-46de-acd6-5f99...
# 2    course-of-action  course-of-action--787fb64d-c87b-4ee5-a341-0ef1...
# 3    course-of-action  course-of-action--b5dbb4c5-b0b1-40b1-80b6-e9e8...
# 4    course-of-action  course-of-action--3efe43d1-6f3f-4fcb-ab39-4a73...
# ..                ...                                                ...
# 262  course-of-action  course-of-action--ec42d8be-f762-4127-80f4-f079...
# 263  course-of-action  course-of-action--f27ef4f2-71fe-48b6-b7f4-02dc...
# 264  course-of-action  course-of-action--f6b7c116-0821-4eb7-9b24-62bd...
# 265  course-of-action  course-of-action--fe0aeb41-1a51-4152-8467-6282...
# 266  course-of-action  course-of-action--25dc1ce8-eb55-4333-ae30-a7cb...
#
#                                      created_by_ref                   created  \
# 0    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2021-08-04T21:22:11.612Z
# 1    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2020-10-19T14:57:58.771Z
# 2    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2019-07-19T14:58:42.715Z
# 3    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2019-07-19T14:40:23.529Z
# 4    identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2019-07-19T14:33:33.543Z
# ..                                              ...                       ...
# 262  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2018-10-17T00:14:20.652Z
# 263  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2018-10-17T00:14:20.652Z
# 264  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2018-10-17T00:14:20.652Z
# 265  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2018-10-17T00:14:20.652Z
# 266  identity--c78cb6e5-0c4b-4611-8297-d1b8b55e40b5  2017-10-25T14:48:53.732Z
#
#                      modified                          mitigation  \
# 0    2021-08-30T15:00:10.680Z                Data Loss Prevention
# 1    2020-10-20T19:52:32.439Z                      Pre-compromise
# 2    2019-07-23T14:44:24.727Z                     Do Not Mitigate
# 3    2020-03-31T13:11:09.471Z              Software Configuration
# 4    2020-03-31T13:11:28.201Z                         Data Backup
# ..                        ...                                 ...
# 262  2019-07-24T19:39:30.292Z       Indicator Blocking Mitigation
# 263  2019-07-25T11:27:03.265Z             Private Keys Mitigation
# 264  2019-07-25T11:25:50.338Z            Port Knocking Mitigation
# 265  2020-01-17T16:45:23.126Z  Modify Existing Service Mitigation
# 266  2018-10-17T00:14:20.652Z      Application Developer Guidance
#
#                                 mitigation_description  \
# 0    Use a data loss prevention (DLP) strategy to c...
# 1    This category is used for any applicable mitig...
# 2    This category is to associate techniques that ...
# 3    Implement configuration changes to software (o...
# 4    Take and store data backups from end user syst...
# ..                                                 ...
# 262  Ensure event tracers/forwarders (Citation: Mic...
# 263  Use strong passphrases for private keys to mak...
# 264  Mitigation of some variants of this technique ...
# 265  Use auditing tools capable of detecting privil...
# 266  This mitigation describes any guidance or trai...
#
#                                             url        matrix mitigation_id  \
# 0    https://attack.mitre.org/mitigations/M1057  mitre-attack         M1057
# 1    https://attack.mitre.org/mitigations/M1056  mitre-attack         M1056
# 2    https://attack.mitre.org/mitigations/M1055  mitre-attack         M1055
# 3    https://attack.mitre.org/mitigations/M1054  mitre-attack         M1054
# 4    https://attack.mitre.org/mitigations/M1053  mitre-attack         M1053
# ..                                          ...           ...           ...
# 262  https://attack.mitre.org/mitigations/T1054  mitre-attack         T1054
# 263  https://attack.mitre.org/mitigations/T1145  mitre-attack         T1145
# 264  https://attack.mitre.org/mitigations/T1205  mitre-attack         T1205
# 265  https://attack.mitre.org/mitigations/T1031  mitre-attack         T1031
# 266  https://attack.mitre.org/mitigations/M1013  mitre-attack         M1013
#
#     x_mitre_attack_spec_version x_mitre_deprecated
# 0                           NaN                NaN
# 1                           NaN                NaN
# 2                           NaN                NaN
# 3                           NaN                NaN
# 4                           NaN                NaN
# ..                          ...                ...
# 262                         NaN               True
# 263                         NaN               True
# 264                         NaN               True
# 265                         NaN               True
# 266                         NaN                NaN
#
# [267 rows x 17 columns]
