# %% [markdown]
# # Actor determination method 3.2: Based on new actors
# This notebook depicts the third methodology for actor determination as described in the corresponding master thesis. Known operations are used as a measure to determine active threat actors. The actors will be ranked based on the date of the first operation, in order to detect whether an actor has just started, and the number of operations. These operations are weighted using an inverse weighting method, ranking recent operations higher. An alternative method is implemented in [Method 3.1](./Method%203_1.ipynb), where the ranking of actors is solely based on the number of operations.
# A graphical representation is depicted in the image below.
#
# The enriched data can then be filtered on the sector and the actors and TTPs will be ranked using the ranking functions. These ranked TTPs are then mapped to controls in order to obtain a prioritization of security controls.
#
# This notebook includes code for experiments on TTP subset sizes to be used in control prioritization.
#
# ![Diagram representation of method 3](./docs/images/Method3.png)

# %% [markdown]
# ## 1. Determine relevant threats  and actors
# ### 1.1. Read ETDA and MITRE data

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt

SECTOR = 'Government'
SECTORS = ['Government', 'Education', 'Healthcare']

YEAR = datetime.date.today().year
YEAR = 2023
INTERVAL = 2
TTP_THRESHOLD = 0

import pandas as pd

merge_df = pd.read_json('ETDA_ATTCK_merge.json',encoding='utf-8')
# df = pd.DataFrame(merge_list)
merge_df['etda_operation_year'].explode().value_counts().sort_index().plot(kind='bar',title="Operations over the years")
# Out:
# <AxesSubplot:title={'center':'Operations over the years'}>

# %% [markdown]
# #### 1.2. Preprocessing

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list if len(x) > 1]) # Convert column of lists to one list and remove single character values

agg_dict = {}
for column in merge_df.columns:
    if column == 'mitre_attack_ttps':
        agg_dict[column] = 'sum'
    else:
        agg_dict[column] = 'first'

merge_df = merge_df.groupby(['etda_name']).agg(agg_dict)
merge_df['mitre_attack_ttps'] = merge_df['mitre_attack_ttps'].apply(lambda x: pd.Series(x).unique())
# Out:
# C:\Users\a.winters\AppData\Local\Temp\ipykernel_4236\773326629.py:12: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   merge_df['mitre_attack_ttps'] = merge_df['mitre_attack_ttps'].apply(lambda x: pd.Series(x).unique())

# %% [markdown]
# #### 1.3. Filter on sector

# %%
def filter_by_sector(df, sector):
    actors_sector_exploded = df.explode('victim_industries')
    return actors_sector_exploded.loc[actors_sector_exploded['victim_industries'] == sector]


def filter_by_sectors(df, sectors):
    actors_sector_exploded = df.explode('victim_industries')
    return actors_sector_exploded.loc[actors_sector_exploded['victim_industries'] in sectors]

actors_filtered = filter_by_sector(merge_df, SECTOR)
actors_filtered['etda_operation_year'].explode().value_counts().sort_index().plot(kind='bar',title="Operations within {} sector over the years".format(SECTOR))
# Out:
# <AxesSubplot:title={'center':'Operations within Government sector over the years'}>

# %% [markdown]
# #### Observation
# How is the date derived? Date of reported breach, or date of actual breach.
#
# Are reports relevant?

# %% [markdown]
# #### 1.4. Count number of recent operations
# Remove actors with no operations

# %%
import numpy as np

def filter_by_operation_year(df, interval):
    years = list(range((YEAR-interval),YEAR+1))
    years = [str(i) for i in years]
    df['etda_operation_year'] = df['etda_operation_year'].apply(lambda x: [i for i in x if i in years])
    return df



actors_filtered = filter_by_operation_year(actors_filtered, INTERVAL)    
actors_filtered['ops_count'] = actors_filtered['etda_operation_year'].apply(len)

# actors_filtered['ops_weight'].nlargest(5).plot(kind='barh',x='etda_name',xlabel='Actor',ylabel='Number of registered operations',title="Top 5 actors targeting {} sector.\nBased on operations between {} and {}".format(SECTOR,YEAR-INTERVAL,YEAR))
# actors_filtered['weight'].nlargest(5).plot(kind='barh',x='etda_name',xlabel='Actor',ylabel='Number of registered operations',title="Top 5 actors targeting {} sector.\nBased on operations between {} and {}".format(SECTOR,YEAR-INTERVAL,YEAR))

# %%
actors_filtered['motivation'].explode().value_counts().plot(kind='barh',title='Motivations of actors')
plt.show()
actors_filtered['country'].value_counts().plot(kind='barh',title='Countries of origin',rot=0)
plt.show()

# %% [markdown]
# ## 2. Rank actors and TTPs
# ### 2.1 Rank actors
# #### 2.1.1 Create weight and sort

# %%
def inverse_square_root(x):
    return 1/np.sqrt(YEAR - int(x) + 1)

def inverse(x):
    return 1/np.exp2(YEAR - int(x) + 1)

actors_filtered = actors_filtered.loc[actors_filtered['ops_count']>0].sort_values(by='ops_count',ascending=False)

actors_filtered['buzz'] = 1/np.sqrt((YEAR - actors_filtered['etda_first_seen'].apply(int) + 1))
actors_filtered['ops_weight'] = actors_filtered['etda_operation_year'].apply(lambda x: sum([inverse(i) for i in x]))
actors_filtered['weight'] = actors_filtered['ops_weight'] * actors_filtered['buzz']

actors_filtered[['etda_first_seen','buzz','ops_count','ops_weight','weight']].sort_values(by='weight',ascending=False)
# Out:
#                                                    etda_first_seen      buzz  \
# etda_name
# Wizard Spider, Gold Blackburn                                 2014  0.316228
# Lazarus Group, Hidden Cobra, Labyrinth Chollima               2007  0.242536
# Gamaredon Group                                               2013  0.301511
# Mummy Spider, TA542                                           2014  0.316228
# Operation Ghostwriter                                         2017  0.377964
# APT 29, Cozy Bear, The Dukes                                  2008  0.250000
# Magic Hound, APT 35, Cobalt Illusion, Charming ...            2012  0.288675
# Reaper, APT 37, Ricochet Chollima, ScarCruft                  2012  0.288675
# SaintBear, Lorec53                                            2021  0.577350
# Kimsuky, Velvet Chollima                                      2012  0.288675
# Mustang Panda, Bronze President                               2012  0.288675
# Sandworm Team, Iron Viking, Voodoo Bear                       2009  0.258199
# Doppel Spider                                                 2019  0.447214
# APT 41                                                        2012  0.288675
# Sofacy, APT 28, Fancy Bear, Sednit                            2004  0.223607
# OilRig, APT 34, Helix Kitten, Chrysene                        2014  0.316228
# Emissary Panda, APT 27, LuckyMouse, Bronze Union              2010  0.267261
# Transparent Tribe, APT 36                                     2013  0.301511
# Turla, Waterbug, Venomous Bear                                1996  0.188982
# Indrik Spider                                                 2007  0.242536
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten              2017  0.377964
# TA2101, Maze Team                                             2019  0.447214
# Bitter                                                        2013  0.301511
# RedDelta                                                      2020  0.500000
# SideWinder, Rattlesnake                                       2012  0.288675
# Curious Gorge                                                 2022  0.707107
# Evilnum                                                       2018  0.408248
# Blind Eagle                                                   2018  0.408248
# FIN7                                                          2013  0.301511
# Moses Staff                                                   2021  0.577350
# Molerats, Extreme Jackal, Gaza Cybergang                      2012  0.288675
# Stone Panda, APT 10, menuPass                                 2006  0.235702
# TA428                                                         2013  0.301511
# Gallium                                                       2018  0.408248
# Aggah                                                         2018  0.408248
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...            2010  0.267261
# Tonto Team, HartBeat, Karma Panda                             2009  0.258199
# Donot Team                                                    2016  0.353553
# Calypso                                                       2016  0.353553
# Silence, Contract Crew                                        2016  0.353553
# APT 42                                                        2015  0.333333
# Gelsemium                                                     2014  0.316228
# InvisiMole                                                    2013  0.301511
# APT 19, Deep Panda, C0d0so0                                   2013  0.301511
# Lotus Blossom, Spring Dragon, Thrip                           2012  0.288675
# Inception Framework, Cloud Atlas                              2012  0.288675
# Desert Falcons                                                2011  0.277350
# Naikon, Lotus Panda                                           2010  0.267261
# El Machete                                                    2010  0.267261
# DarkHotel                                                     2007  0.242536
# Mikroceen                                                     2017  0.377964
# IronHusky                                                     2017  0.377964
# PKPLUG                                                        2016  0.353553
# RedAlpha                                                      2015  0.333333
# RedFoxtrot                                                    2014  0.316228
# Patchwork, Dropping Elephant                                  2013  0.301511
# Bronze Butler, Tick, RedBaldNight, Stalker Panda              2010  0.267261
# Winnti Group, Blackfly, Wicked Panda                          2010  0.267261
# TaskMasters                                                   2010  0.267261
#
#                                                     ops_count  ops_weight  \
# etda_name
# Wizard Spider, Gold Blackburn                              48       8.125
# Lazarus Group, Hidden Cobra, Labyrinth Chollima            25       5.250
# Gamaredon Group                                            15       3.625
# Mummy Spider, TA542                                        14       3.250
# Operation Ghostwriter                                      11       2.500
# APT 29, Cozy Bear, The Dukes                               19       3.000
# Magic Hound, APT 35, Cobalt Illusion, Charming ...         12       2.375
# Reaper, APT 37, Ricochet Chollima, ScarCruft               11       2.375
# SaintBear, Lorec53                                          4       1.000
# Kimsuky, Velvet Chollima                                    8       1.750
# Mustang Panda, Bronze President                             8       1.750
# Sandworm Team, Iron Viking, Voodoo Bear                     6       1.750
# Doppel Spider                                               7       0.875
# APT 41                                                      9       1.250
# Sofacy, APT 28, Fancy Bear, Sednit                          7       1.375
# OilRig, APT 34, Helix Kitten, Chrysene                      4       0.875
# Emissary Panda, APT 27, LuckyMouse, Bronze Union            5       1.000
# Transparent Tribe, APT 36                                   5       0.875
# Turla, Waterbug, Venomous Bear                              7       1.375
# Indrik Spider                                               8       1.000
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten            5       0.625
# TA2101, Maze Team                                           3       0.500
# Bitter                                                      3       0.625
# RedDelta                                                    2       0.375
# SideWinder, Rattlesnake                                     3       0.625
# Curious Gorge                                               1       0.250
# Evilnum                                                     2       0.375
# Blind Eagle                                                 2       0.375
# FIN7                                                        3       0.500
# Moses Staff                                                 1       0.250
# Molerats, Extreme Jackal, Gaza Cybergang                    4       0.500
# Stone Panda, APT 10, menuPass                               3       0.500
# TA428                                                       2       0.375
# Gallium                                                     1       0.250
# Aggah                                                       2       0.250
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...          2       0.375
# Tonto Team, HartBeat, Karma Panda                           2       0.375
# Donot Team                                                  1       0.250
# Calypso                                                     2       0.250
# Silence, Contract Crew                                      1       0.250
# APT 42                                                      1       0.250
# Gelsemium                                                   2       0.250
# InvisiMole                                                  1       0.250
# APT 19, Deep Panda, C0d0so0                                 1       0.250
# Lotus Blossom, Spring Dragon, Thrip                         1       0.250
# Inception Framework, Cloud Atlas                            1       0.250
# Desert Falcons                                              2       0.250
# Naikon, Lotus Panda                                         1       0.250
# El Machete                                                  1       0.250
# DarkHotel                                                   2       0.250
# Mikroceen                                                   1       0.125
# IronHusky                                                   1       0.125
# PKPLUG                                                      1       0.125
# RedAlpha                                                    1       0.125
# RedFoxtrot                                                  1       0.125
# Patchwork, Dropping Elephant                                1       0.125
# Bronze Butler, Tick, RedBaldNight, Stalker Panda            1       0.125
# Winnti Group, Blackfly, Wicked Panda                        1       0.125
# TaskMasters                                                 1       0.125
#
#                                                       weight
# etda_name
# Wizard Spider, Gold Blackburn                       2.569351
# Lazarus Group, Hidden Cobra, Labyrinth Chollima     1.273312
# Gamaredon Group                                     1.092979
# Mummy Spider, TA542                                 1.027740
# Operation Ghostwriter                               0.944911
# APT 29, Cozy Bear, The Dukes                        0.750000
# Magic Hound, APT 35, Cobalt Illusion, Charming ...  0.685603
# Reaper, APT 37, Ricochet Chollima, ScarCruft        0.685603
# SaintBear, Lorec53                                  0.577350
# Kimsuky, Velvet Chollima                            0.505181
# Mustang Panda, Bronze President                     0.505181
# Sandworm Team, Iron Viking, Voodoo Bear             0.451848
# Doppel Spider                                       0.391312
# APT 41                                              0.360844
# Sofacy, APT 28, Fancy Bear, Sednit                  0.307459
# OilRig, APT 34, Helix Kitten, Chrysene              0.276699
# Emissary Panda, APT 27, LuckyMouse, Bronze Union    0.267261
# Transparent Tribe, APT 36                           0.263822
# Turla, Waterbug, Venomous Bear                      0.259851
# Indrik Spider                                       0.242536
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten    0.236228
# TA2101, Maze Team                                   0.223607
# Bitter                                              0.188445
# RedDelta                                            0.187500
# SideWinder, Rattlesnake                             0.180422
# Curious Gorge                                       0.176777
# Evilnum                                             0.153093
# Blind Eagle                                         0.153093
# FIN7                                                0.150756
# Moses Staff                                         0.144338
# Molerats, Extreme Jackal, Gaza Cybergang            0.144338
# Stone Panda, APT 10, menuPass                       0.117851
# TA428                                               0.113067
# Gallium                                             0.102062
# Aggah                                               0.102062
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...  0.100223
# Tonto Team, HartBeat, Karma Panda                   0.096825
# Donot Team                                          0.088388
# Calypso                                             0.088388
# Silence, Contract Crew                              0.088388
# APT 42                                              0.083333
# Gelsemium                                           0.079057
# InvisiMole                                          0.075378
# APT 19, Deep Panda, C0d0so0                         0.075378
# Lotus Blossom, Spring Dragon, Thrip                 0.072169
# Inception Framework, Cloud Atlas                    0.072169
# Desert Falcons                                      0.069338
# Naikon, Lotus Panda                                 0.066815
# El Machete                                          0.066815
# DarkHotel                                           0.060634
# Mikroceen                                           0.047246
# IronHusky                                           0.047246
# PKPLUG                                              0.044194
# RedAlpha                                            0.041667
# RedFoxtrot                                          0.039528
# Patchwork, Dropping Elephant                        0.037689
# Bronze Butler, Tick, RedBaldNight, Stalker Panda    0.033408
# Winnti Group, Blackfly, Wicked Panda                0.033408
# TaskMasters                                         0.033408

# %%
def normalize(df):
    return (df-df.min())/(df.max()-df.min())

actors_filtered['actor_weight'] = normalize(actors_filtered['weight'])

actors_filtered.sort_values(by='actor_weight',ascending=False,inplace=True)

actors_ranked = actors_filtered[['actor_weight','mitre_attack_ttps']]
unique_ttps = to_1D(actors_ranked['mitre_attack_ttps']).value_counts()

print('Number of actors:',actors_ranked.index.size)
print('Number of TTPs:\t', unique_ttps.index.size)
# Out:
# Number of actors: 59
# Number of TTPs:	 321

# %%
actor_weights = actors_ranked['actor_weight']
actor_weights.nlargest(5).plot(kind='barh',xlabel='Actor Name', title="Top 5 actors targeting {} sector based on operations between {} and {} (normalized)".format(SECTOR,YEAR-INTERVAL,YEAR))
# Out:
# <AxesSubplot:title={'center':'Top 5 actors targeting Government sector based on operations between 2021 and 2023 (normalized)'}, ylabel='Actor Name'>

# %%
actors_filtered.columns
# Out:
# Index(['mitre_attack_id', 'mitre_attack_name', 'mitre_attack_aliases',
#        'mitre_attack_created', 'mitre_attack_last_modified', 'mitre_url',
#        'etda_id', 'etda_name', 'etda_aliases', 'etda_first_seen', 'etda_url',
#        'etda_operation_dates', 'etda_operation_year', 'country', 'motivation',
#        'victim_industries', 'victim_countries', 'mitre_attack_ttps',
#        'ops_count', 'buzz', 'ops_weight', 'weight', 'actor_weight'],
#       dtype='object')

# %% [markdown]
# #### Observations
# Since the Government sector is the most represented in the ETDA dataset, this one is chosen for the tests. 13 of the actors from the reports target this sector. APT 29 is mentioned the most across reports. This is due to their notorious SolarWinds attack in 2020, which is mentioned often. In 2021 they also launched a big spear-phishing campaign. This actor is followed by Wizard Spider, a ransomware actor that is very active.
#
# It is mainly these two actors that exceed the others in terms of how often they are mentioned. The other mentioned actors have a weigth just below 1.0.

# %% [markdown]
# ### 2.2. Rank TTPs
# #### 2.3.1 Explode dataframe per TTP
# Explode the dataframe per TTP. Now a weighting calculation can be done per TTP, based on the information provided. Information includes the actor results (and kill chain phase).
#
# For now: the actor weights are summed per TTP to obtain a ranking per TTP.

# %%
actors_ranked['number_of_actors'] = 1
actors_ttp_exploded = actors_ranked.explode('mitre_attack_ttps')
# Out:
# C:\Users\a.winters\AppData\Local\Temp\ipykernel_4236\823944124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors_ranked['number_of_actors'] = 1

# %% [markdown]
# #### 2.3.2. Group by TTP and sum actor weights
# Sum the actor weights.

# %%
actors_ttp_summed = actors_ttp_exploded.reset_index(drop=True)
ttps_ranked = actors_ttp_summed.groupby('mitre_attack_ttps').sum()
print(ttps_ranked.sort_values(by='actor_weight',ascending=False))
# Out:
#                    actor_weight  number_of_actors
# mitre_attack_ttps
# T1027                  4.593448                31
# T1204.002              4.411693                31
# T1059.003              4.312603                26
# T1566.001              4.201165                30
# T1059.001              4.179007                28
# ...                         ...               ...
# T1137.006              0.013174                 1
# T1032                  0.013174                 1
# T1497                  0.010736                 1
# T1029                  0.010736                 1
# T1587.002              0.001688                 1
#
# [321 rows x 2 columns]

# %% [markdown]
# #### 2.3.3 Enrich TTP information
# Information from the ATT&CK data is used via the attackcti package.

# %%
from attackcti import attack_client
from pandas import json_normalize
import sys

mitre_columns = ['technique_id','technique','tactic','technique_detection']

def get_attck_dataframe(matrix = 'enterprise'):
    if  (matrix.lower() == 'enterprise'):
        # Instantiating attack_client class
        lift = attack_client()
        # Getting techniques for windows platform - enterprise matrix
        attck = lift.get_enterprise_techniques(stix_format = False)
        # Generating a dataframe with information collected
        attck = json_normalize(attck)
        return attck
    else:
        sys.exit('ERROR: Only Enterprise available!!')

attck = get_attck_dataframe()
attck = attck[mitre_columns]

ttps_enriched = pd.merge(ttps_ranked,attck,how='left',left_index=True,right_on='technique_id')
ttps_enriched.index = ttps_ranked.index
ttps_enriched['technique_name_id'] = ttps_enriched['technique'] + " (" + ttps_enriched['technique_id'] + ")"
# Out:
# [taxii2client.v20] [WARNING ] [2023-06-05 16:58:56,866] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2023-06-05 16:58:56,908] TAXII Server Response with different amount of objects! Setting per_request=750

# %% [markdown]
# #### 2.3.4. Calculate weights

# %%
ttps_enriched['ttp_weight'] = normalize(ttps_enriched['actor_weight'])
ttps_enriched = ttps_enriched.drop(['actor_weight','technique_id'],axis=1)
ttps_enriched
# Out:
#                    number_of_actors  \
# mitre_attack_ttps
# Not Available                    19
# T1001.001                         1
# T1001.002                         1
# T1001.003                         2
# T1003                             2
# ...                             ...
# T1614.001                         2
# T1615                             1
# T1620                             1
# T1621                             1
# T1649                             1
#
#                                                         technique  \
# mitre_attack_ttps
# Not Available                                                 NaN
# T1001.001                                               Junk Data
# T1001.002                                           Steganography
# T1001.003                                  Protocol Impersonation
# T1003                                       OS Credential Dumping
# ...                                                           ...
# T1614.001                               System Language Discovery
# T1615                                      Group Policy Discovery
# T1620                                     Reflective Code Loading
# T1621              Multi-Factor Authentication Request Generation
# T1649                  Steal or Forge Authentication Certificates
#
#                                   tactic  \
# mitre_attack_ttps
# Not Available                        NaN
# T1001.001          [command-and-control]
# T1001.002          [command-and-control]
# T1001.003          [command-and-control]
# T1003                [credential-access]
# ...                                  ...
# T1614.001                    [discovery]
# T1615                        [discovery]
# T1620                  [defense-evasion]
# T1621                [credential-access]
# T1649                [credential-access]
#
#                                                  technique_detection  \
# mitre_attack_ttps
# Not Available                                                    NaN
# T1001.001          Analyze network data for uncommon data flows (...
# T1001.002          Analyze network data for uncommon data flows (...
# T1001.003          Analyze network data for uncommon data flows (...
# T1003              ### Windows\nMonitor for unexpected processes ...
# ...                                                              ...
# T1614.001          System and network discovery techniques normal...
# T1615              System and network discovery techniques normal...
# T1620              Monitor for code artifacts associated with ref...
# T1621              Monitor user account logs as well as 2FA/MFA a...
# T1649
#
#                                                    technique_name_id  \
# mitre_attack_ttps
# Not Available                                                    NaN
# T1001.001                                      Junk Data (T1001.001)
# T1001.002                                  Steganography (T1001.002)
# T1001.003                         Protocol Impersonation (T1001.003)
# T1003                                  OS Credential Dumping (T1003)
# ...                                                              ...
# T1614.001                      System Language Discovery (T1614.001)
# T1615                                 Group Policy Discovery (T1615)
# T1620                                Reflective Code Loading (T1620)
# T1621              Multi-Factor Authentication Request Generation...
# T1649              Steal or Forge Authentication Certificates (T1...
#
#                    ttp_weight
# mitre_attack_ttps
# Not Available        0.273612
# T1001.001            0.023167
# T1001.002            0.061172
# T1001.003            0.108451
# T1003                0.028613
# ...                       ...
# T1614.001            0.111851
# T1615                0.019079
# T1620                0.106113
# T1621                0.061172
# T1649                0.061172
#
# [321 rows x 6 columns]

# %% [markdown]
# #### Statistics

# %%
ttps_enriched.nlargest(10,columns='ttp_weight').plot.barh(y='ttp_weight',x='technique_name_id',xlabel="TTP Name and ATT&CK ID" ,title="Top 10 techniques for actors targeting {} sector".format(SECTOR))

# ttps_enriched.plot.hist(column="number_of_actors",bins=10, title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR))
ttps_enriched = ttps_enriched.drop(['number_of_actors'],axis=1)

# %% [markdown]
# Only take the top percentage of the TTPs

# %%
PERCENTAGE = 1

def take_percentage(percentage,df):
    top_percent = int(len(df) * PERCENTAGE)
    print("Taking {}%; {} entries".format(percentage*100,top_percent))
    return df.nlargest(top_percent,columns="ttp_weight")

def take_threshold(threshold, df):
    return df.loc[df['ttp_weight']>threshold]


ttps_enriched = take_percentage(PERCENTAGE,ttps_enriched)
ttps_enriched.sort_values(by="ttp_weight",inplace=True,ascending=False)
# ttps_enriched = take_threshold(TTP_THRESHOLD,ttps_enriched)
# Out:
# Taking 100%; 321 entries

# %% [markdown]
# #### Observations
# Within the tested Government sector, the top 10 techniques used are shown above.
# The top technique is '[Obfuscated Files or Information](https://attack.mitre.org/techniques/T1027/)', where adversaries obfuscate the contents of an executable or file by encrypting, encoding, compressing or otherwise obscuring them on the system or in transit. This is common behavior to evade defenses.
#
# The second technique is '[Tool]'(https://attack.mitre.org/techniques/T1588/002/), is described as "Adversaries may buy, steal or download software tools that can be used during targeting." This is a very generic technique, since the use of the use of tools is common among hackers and there exists a wide variety of tools, hence why it is listed in such a high position.

# %% [markdown]
# ## 3. Control prioritization

# %% [markdown]
# ### 3.1 Control Mapping
# Source of the mapping: [Security Control Framework Mappings to ATT&CK](https://github.com/center-for-threat-informed-defense/attack-control-framework-mappings).
#
# This maps controls from NIST 800-53 to MITRE ATT&CK. The following versions are considered:
# - MITRE ATT&CK v10.1
# - NIST 800-53 Revision 5

# %%
# Load ATT&CK to NIST 800-53 mapping
def get_nist_attck_mapping():
    nist_attck_mapping = pd.read_excel("data/mappings/nist800-53-r5-mappings.xlsx")
    nist_attck_mapping = nist_attck_mapping.drop(["Mapping Type","Technique Name"],axis=1)
    return nist_attck_mapping

def get_cis_attck_mapping():
    return None

def get_iso_attck_mapping():
    iso_attck_mapping = pd.read_excel("data/mappings/ISO_27001_2022_ATTCKv82.xlsx")
    return iso_attck_mapping

# %% [markdown]
# Merge the TTPs with the controls. Only keep the TTPs that have a weight above a certain threshold. This threshold will be experimented with. The following values are considered:
# - All TTPs
# - threshold > 0.25
# - threshold > 0.5
# - threshold > 0.7
# - threshold > 0.9

# %%
ttp_control_map = get_iso_attck_mapping()

ttp_control_merge = ttp_control_map.merge(ttps_enriched, left_on="Technique ID", right_on="mitre_attack_ttps",how="inner")
ttp_control_merge.sort_values(by='ttp_weight',inplace=True,ascending=False)
print("Number of TTPS:",ttp_control_merge['Technique ID'].value_counts().index.size)
print("Number of controls:",ttp_control_merge['Control ID'].value_counts().index.size)
ttp_control_merge
# Out:
# Number of TTPS: 202
# Number of controls: 42
#       Control ID Technique ID  \
# 562         8.16        T1027
# 559         8.80        T1027
# 560         8.70        T1027
# 561         8.10        T1027
# 1252        6.30    T1204.002
# ...          ...          ...
# 298         8.18        T1072
# 301         5.30        T1072
# 688         8.16        T1029
# 687         8.21        T1029
# 686         8.80        T1029
#
#                                            Control Name  \
# 562                               Monitoring activities
# 559             Management of technical vulnerabilities
# 560                          Protection against malware
# 561                               User endpoint devices
# 1252  Information security awareness, education and ...
# ...                                                 ...
# 298                  Use of privileged utility programs
# 301                               Segregation of duties
# 688                               Monitoring activities
# 687                        Security of network services
# 686             Management of technical vulnerabilities
#
#                             technique                         tactic  \
# 562   Obfuscated Files or Information              [defense-evasion]
# 559   Obfuscated Files or Information              [defense-evasion]
# 560   Obfuscated Files or Information              [defense-evasion]
# 561   Obfuscated Files or Information              [defense-evasion]
# 1252                   Malicious File                    [execution]
# ...                               ...                            ...
# 298         Software Deployment Tools  [execution, lateral-movement]
# 301         Software Deployment Tools  [execution, lateral-movement]
# 688                Scheduled Transfer                 [exfiltration]
# 687                Scheduled Transfer                 [exfiltration]
# 686                Scheduled Transfer                 [exfiltration]
#
#                                     technique_detection  \
# 562   Detection of file obfuscation is difficult unl...
# 559   Detection of file obfuscation is difficult unl...
# 560   Detection of file obfuscation is difficult unl...
# 561   Detection of file obfuscation is difficult unl...
# 1252  Monitor the execution of and command-line argu...
# ...                                                 ...
# 298   Detection methods will vary depending on the t...
# 301   Detection methods will vary depending on the t...
# 688   Monitor process file access patterns and netwo...
# 687   Monitor process file access patterns and netwo...
# 686   Monitor process file access patterns and netwo...
#
#                             technique_name_id  ttp_weight
# 562   Obfuscated Files or Information (T1027)    1.000000
# 559   Obfuscated Files or Information (T1027)    1.000000
# 560   Obfuscated Files or Information (T1027)    1.000000
# 561   Obfuscated Files or Information (T1027)    1.000000
# 1252               Malicious File (T1204.002)    0.960417
# ...                                       ...         ...
# 298         Software Deployment Tools (T1072)    0.004354
# 301         Software Deployment Tools (T1072)    0.004354
# 688                Scheduled Transfer (T1029)    0.001970
# 687                Scheduled Transfer (T1029)    0.001970
# 686                Scheduled Transfer (T1029)    0.001970
#
# [1675 rows x 8 columns]

# %% [markdown]
# Get TTPs incl number of controls that mitigate them

# %%
ttp_control_merge[['Technique ID','ttp_weight']].drop_duplicates().plot(kind='hist',bins=30,title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR))
# ttp_control_merge['ttp_weight'].plot(kind='hist',bins=30,title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR),xlabel="TTP weights")
# Out:
# <AxesSubplot:title={'center':'Distribution of TTP weights for actors targeting Government sector'}, ylabel='Frequency'>

# %% [markdown]
# **Observations**
#
# The TTP weights are a normalised summation of the actor weights. This means, the higher the TTP weight, the more (high weighted) actors share this TTP.
# We can see that the distribution of TTP weights is a right-skewed distribution. This is expected, since this means that the number of TTPs that are shared by these actors is

# %%
# ttp_control_merge[['Control ID','Control Name']].value_counts().nlargest(10).plot(kind='barh',title="Number of selected TTPs mitigated per control")

ttp_control_ranked = ttp_control_merge.groupby(['Control ID','Control Name']).sum()
ttp_control_ranked.sort_values(by='ttp_weight',ascending=False, inplace=True)

# ttp_control_ranked.nlargest(10,columns='ttp_weight').plot(kind='barh',title="Top controls by number of mitigated TTPs. No TTP threshold")
ttp_control_ranked.nlargest(10,columns='ttp_weight').plot(kind='barh',title="Top controls by number of mitigated TTPs. Top {}% of TTPS".format(PERCENTAGE*100))
# Out:
# <AxesSubplot:title={'center':'Top controls by number of mitigated TTPs. Top 100% of TTPS'}, ylabel='Control ID,Control Name'>

# %% [markdown]
# #### Observations
# There are some controls that map to a lot of TTPs. For the complete results for the ‘Government’ sector, there are 215 TTPs and 106 controls. Merging the two gives a resulting set of 2545 mappings. Since there is no measure of control effectiveness to a TTP in this data, they are sorted based on the TTPs they control and their respective weights.
#
# There are two ways to approach the control mapping, either a generic approach or a targeted approach.
# - Targeted: Take the most prominent TTPs, those with the highest weights, and display the controls for this.
# - Generic: Take the complete, or near-complete, set of TTPs used by the actors. Rank the controls based on the number of TTPs they control and their respective weights. The downside of this is that controls that map to a large number of TTPs will probably always end up on top. This means that the initial TTP ranking matters less.
#
# When simply counting the number of TTPs that a control covers, only the general ones come to the top. Even if the TTP weights are considered. One possibility to solve this, is to only take the top x% of TTPs into consideration.

# %% [markdown]
# # Get TTPs mitigated by said control

# %%
control_id = 8.1
ttp_control_merge.loc[ttp_control_merge['Control ID'] == control_id]
# Out:
#       Control ID Technique ID           Control Name  \
# 561          8.1        T1027  User endpoint devices
# 543          8.1    T1059.001  User endpoint devices
# 973          8.1    T1053.005  User endpoint devices
# 1286         8.1    T1562.001  User endpoint devices
# 530          8.1    T1059.005  User endpoint devices
# ...          ...          ...                    ...
# 1005         8.1    T1137.001  User endpoint devices
# 1476         8.1    T1218.007  User endpoint devices
# 260          8.1    T1546.011  User endpoint devices
# 825          8.1    T1558.001  User endpoint devices
# 286          8.1        T1072  User endpoint devices
#
#                             technique  \
# 561   Obfuscated Files or Information
# 543                        PowerShell
# 973                    Scheduled Task
# 1286          Disable or Modify Tools
# 530                      Visual Basic
# ...                               ...
# 1005           Office Template Macros
# 1476                          Msiexec
# 260              Application Shimming
# 825                     Golden Ticket
# 286         Software Deployment Tools
#
#                                               tactic  \
# 561                                [defense-evasion]
# 543                                      [execution]
# 973   [execution, persistence, privilege-escalation]
# 1286                               [defense-evasion]
# 530                                      [execution]
# ...                                              ...
# 1005                                   [persistence]
# 1476                               [defense-evasion]
# 260              [privilege-escalation, persistence]
# 825                              [credential-access]
# 286                    [execution, lateral-movement]
#
#                                     technique_detection  \
# 561   Detection of file obfuscation is difficult unl...
# 543   If proper execution policy is set, adversaries...
# 973   Monitor process execution from the <code>svcho...
# 1286  Monitor processes and command-line arguments t...
# 530   Monitor for events associated with VB executio...
# ...                                                 ...
# 1005  Many Office-related persistence mechanisms req...
# 1476  Use process monitoring to monitor the executio...
# 260   There are several public tools available that ...
# 825   Monitor for anomalous Kerberos activity, such ...
# 286   Detection methods will vary depending on the t...
#
#                             technique_name_id  ttp_weight
# 561   Obfuscated Files or Information (T1027)    1.000000
# 543                    PowerShell (T1059.001)    0.909742
# 973                Scheduled Task (T1053.005)    0.805416
# 1286      Disable or Modify Tools (T1562.001)    0.674488
# 530                  Visual Basic (T1059.005)    0.621307
# ...                                       ...         ...
# 1005       Office Template Macros (T1137.001)    0.017050
# 1476                      Msiexec (T1218.007)    0.012028
# 260          Application Shimming (T1546.011)    0.009710
# 825                 Golden Ticket (T1558.001)    0.005370
# 286         Software Deployment Tools (T1072)    0.004354
#
# [113 rows x 8 columns]

# %% [markdown]
# # Export results
# Export the results to an excel with three sheets:
# - Actors
# - TTPs
# - Controls

# %%
writer = pd.ExcelWriter("results/Result Sheet {} Sector {}-{}.xlsx".format(SECTOR,YEAR-INTERVAL,YEAR),engine="xlsxwriter")

ttp_control_ranked.to_excel(writer,sheet_name="Controls")
ttp_control_merge.to_excel(writer,sheet_name="TTP and Control mitigations",index=False)
ttps_enriched.to_excel(writer,sheet_name="TTPs")
actors_filtered[['etda_url','country','motivation','victim_industries','victim_countries','etda_first_seen','buzz','ops_count','ops_weight','weight']].to_excel(writer,sheet_name="Actors")

writer.close()
