# %% [markdown]
# # Actor determination method 3.2: Based on new actors
# This notebook depicts the third methodology for actor determination as described in the corresponding master thesis. Known operations are used as a measure to determine active threat actors. The actors will be ranked based on the date of the first operation, in order to detect whether an actor has just started, and the number of operations. These operations are weighted using an inverse weighting method, ranking recent operations higher. An alternative method is implemented in [Method 3.1](./Method%203_1.ipynb), where the ranking of actors is solely based on the number of operations.
# A graphical representation is depicted in the image below.
#
# The enriched data can then be filtered on the sector and the actors and TTPs will be ranked using the ranking functions. These ranked TTPs are then mapped to controls in order to obtain a prioritization of security controls.
#
# This notebook includes code for experiments on TTP subset sizes to be used in control prioritization.
#
# ![Diagram representation of method 3](./docs/images/Method3.png)

# %% [markdown]
# ## 1. Determine relevant threats  and actors
# ### 1.1. Read ETDA and MITRE data

# %%
import datetime
import pandas as pd

SECTOR = 'Government'

YEAR = datetime.date.today().year
YEAR = 2023
INTERVAL = 2
TTP_THRESHOLD = 0

import pandas as pd

merge_df = pd.read_json('ETDA_ATTCK_merge.json',encoding='utf-8')
# df = pd.DataFrame(merge_list)
merge_df['etda_operation_year'].explode().value_counts().sort_index().plot(kind='bar',title="Operations over the years")
# Out:
# <AxesSubplot:title={'center':'Operations over the years'}>

# %% [markdown]
# #### 1.2. Preprocessing

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list if len(x) > 1]) # Convert column of lists to one list and remove single character values

agg_dict = {}
for column in merge_df.columns:
    if column == 'mitre_attack_ttps':
        agg_dict[column] = 'sum'
    else:
        agg_dict[column] = 'first'

merge_df = merge_df.groupby(['etda_name']).agg(agg_dict)
merge_df['mitre_attack_ttps'] = merge_df['mitre_attack_ttps'].apply(lambda x: pd.Series(x).unique())
# Out:
# C:\Users\a.winters\AppData\Local\Temp\ipykernel_14632\773326629.py:12: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   merge_df['mitre_attack_ttps'] = merge_df['mitre_attack_ttps'].apply(lambda x: pd.Series(x).unique())

# %% [markdown]
# #### 1.3. Filter on sector

# %%
def filter_by_sector(df, sector):
    actors_sector_exploded = df.explode('victim_industries')
    return actors_sector_exploded.loc[actors_sector_exploded['victim_industries'] == sector]

actors_filtered = filter_by_sector(merge_df, SECTOR)
actors_filtered['etda_operation_year'].explode().value_counts().sort_index().plot(kind='bar',title="Operations within {} sector over the years".format(SECTOR))
# Out:
# <AxesSubplot:title={'center':'Operations within Government sector over the years'}>

# %% [markdown]
# #### Observation
# How is the date derived? Date of reported breach, or date of actual breach.
#
# Are reports relevant?

# %% [markdown]
# #### 1.4. Count number of recent operations
# Remove actors with no operations

# %%
import numpy as np

def filter_by_operation_year(df, interval):
    years = list(range((YEAR-interval),YEAR+1))
    years = [str(i) for i in years]
    df['etda_operation_year'] = df['etda_operation_year'].apply(lambda x: [i for i in x if i in years])
    return df



actors_filtered = filter_by_operation_year(actors_filtered, INTERVAL)    
actors_filtered['ops_count'] = actors_filtered['etda_operation_year'].apply(len)

# actors_filtered['ops_weight'].nlargest(5).plot(kind='barh',x='etda_name',xlabel='Actor',ylabel='Number of registered operations',title="Top 5 actors targeting {} sector.\nBased on operations between {} and {}".format(SECTOR,YEAR-INTERVAL,YEAR))
# actors_filtered['weight'].nlargest(5).plot(kind='barh',x='etda_name',xlabel='Actor',ylabel='Number of registered operations',title="Top 5 actors targeting {} sector.\nBased on operations between {} and {}".format(SECTOR,YEAR-INTERVAL,YEAR))

# %%
actors_filtered['ops_count'].plot(kind='hist',bins=20,x='etda_name',xlabel='Actor',ylabel='Number of registered operations',title="Distribution of actor operations from actors targeting {} sector.\nOperations between {} and {}".format(SECTOR,YEAR-INTERVAL,YEAR))
# Out:
# <AxesSubplot:title={'center':'Distribution of actor operations from actors targeting Government sector.\nOperations between 2021 and 2023'}, ylabel='Frequency'>

# %% [markdown]
# ## 2. Rank actors and TTPs
# ### 2.1 Rank actors
# #### 2.1.1 Create weight and sort
# TODO: Define weight calculation

# %%
def inverse_square_root(x):
    return 1/np.sqrt(YEAR - int(x) + 1)

def inverse(x):
    return 1/(YEAR - int(x) + 1)

actors_filtered = actors_filtered.loc[actors_filtered['ops_count']>0].sort_values(by='ops_count',ascending=False)

actors_filtered['buzz'] = 1/(YEAR - actors_filtered['etda_first_seen'].apply(int) + 1)
actors_filtered['ops_weight'] = actors_filtered['etda_operation_year'].apply(lambda x: sum([inverse(i) for i in x]))
actors_filtered['weight'] = actors_filtered['ops_weight'] * actors_filtered['buzz']

actors_filtered[['etda_first_seen','buzz','ops_count','ops_weight','weight']].sort_values(by='weight',ascending=False)

actors_filtered.to_csv
# Out:
#                                                    etda_first_seen      buzz  \
# etda_name
# Wizard Spider, Gold Blackburn                                 2014  0.100000
# Operation Ghostwriter                                         2017  0.142857
# Gamaredon Group                                               2013  0.090909
# Mummy Spider, TA542                                           2014  0.100000
# SaintBear, Lorec53                                            2021  0.333333
# Lazarus Group, Hidden Cobra, Labyrinth Chollima               2007  0.058824
# Doppel Spider                                                 2019  0.200000
# APT 29, Cozy Bear, The Dukes                                  2008  0.062500
# Magic Hound, APT 35, Cobalt Illusion, Charming ...            2012  0.083333
# Reaper, APT 37, Ricochet Chollima, ScarCruft                  2012  0.083333
# Kimsuky, Velvet Chollima                                      2012  0.083333
# Mustang Panda, Bronze President                               2012  0.083333
# APT 41                                                        2012  0.083333
# Curious Gorge                                                 2022  0.500000
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten              2017  0.142857
# Sandworm Team, Iron Viking, Voodoo Bear                       2009  0.066667
# TA2101, Maze Team                                             2019  0.200000
# RedDelta                                                      2020  0.250000
# OilRig, APT 34, Helix Kitten, Chrysene                        2014  0.100000
# Transparent Tribe, APT 36                                     2013  0.090909
# Moses Staff                                                   2021  0.333333
# Indrik Spider                                                 2007  0.058824
# Emissary Panda, APT 27, LuckyMouse, Bronze Union              2010  0.071429
# Sofacy, APT 28, Fancy Bear, Sednit                            2004  0.050000
# Blind Eagle                                                   2018  0.166667
# Evilnum                                                       2018  0.166667
# Bitter                                                        2013  0.090909
# Molerats, Extreme Jackal, Gaza Cybergang                      2012  0.083333
# SideWinder, Rattlesnake                                       2012  0.083333
# Aggah                                                         2018  0.166667
# Turla, Waterbug, Venomous Bear                                1996  0.035714
# FIN7                                                          2013  0.090909
# Gallium                                                       2018  0.166667
# Calypso                                                       2016  0.125000
# TA428                                                         2013  0.090909
# Gelsemium                                                     2014  0.100000
# Stone Panda, APT 10, menuPass                                 2006  0.055556
# Silence, Contract Crew                                        2016  0.125000
# Donot Team                                                    2016  0.125000
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...            2010  0.071429
# Tonto Team, HartBeat, Karma Panda                             2009  0.066667
# APT 42                                                        2015  0.111111
# Desert Falcons                                                2011  0.076923
# IronHusky                                                     2017  0.142857
# Mikroceen                                                     2017  0.142857
# InvisiMole                                                    2013  0.090909
# APT 19, Deep Panda, C0d0so0                                   2013  0.090909
# PKPLUG                                                        2016  0.125000
# Lotus Blossom, Spring Dragon, Thrip                           2012  0.083333
# Inception Framework, Cloud Atlas                              2012  0.083333
# DarkHotel                                                     2007  0.058824
# RedAlpha                                                      2015  0.111111
# El Machete                                                    2010  0.071429
# Naikon, Lotus Panda                                           2010  0.071429
# RedFoxtrot                                                    2014  0.100000
# Patchwork, Dropping Elephant                                  2013  0.090909
# Bronze Butler, Tick, RedBaldNight, Stalker Panda              2010  0.071429
# Winnti Group, Blackfly, Wicked Panda                          2010  0.071429
# TaskMasters                                                   2010  0.071429
#
#                                                     ops_count  ops_weight  \
# etda_name
# Wizard Spider, Gold Blackburn                              48   18.833333
# Operation Ghostwriter                                      11    5.166667
# Gamaredon Group                                            15    7.500000
# Mummy Spider, TA542                                        14    6.666667
# SaintBear, Lorec53                                          4    2.000000
# Lazarus Group, Hidden Cobra, Labyrinth Chollima            25   11.166667
# Doppel Spider                                               7    2.333333
# APT 29, Cozy Bear, The Dukes                               19    7.166667
# Magic Hound, APT 35, Cobalt Illusion, Charming ...         12    5.166667
# Reaper, APT 37, Ricochet Chollima, ScarCruft               11    5.166667
# Kimsuky, Velvet Chollima                                    8    3.833333
# Mustang Panda, Bronze President                             8    3.666667
# APT 41                                                      9    3.166667
# Curious Gorge                                               1    0.500000
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten            5    1.666667
# Sandworm Team, Iron Viking, Voodoo Bear                     6    3.500000
# TA2101, Maze Team                                           3    1.166667
# RedDelta                                                    2    0.833333
# OilRig, APT 34, Helix Kitten, Chrysene                      4    1.833333
# Transparent Tribe, APT 36                                   5    2.000000
# Moses Staff                                                 1    0.500000
# Indrik Spider                                               8    2.666667
# Emissary Panda, APT 27, LuckyMouse, Bronze Union            5    2.166667
# Sofacy, APT 28, Fancy Bear, Sednit                          7    3.000000
# Blind Eagle                                                 2    0.833333
# Evilnum                                                     2    0.833333
# Bitter                                                      3    1.333333
# Molerats, Extreme Jackal, Gaza Cybergang                    4    1.333333
# SideWinder, Rattlesnake                                     3    1.333333
# Aggah                                                       2    0.666667
# Turla, Waterbug, Venomous Bear                              7    3.000000
# FIN7                                                        3    1.166667
# Gallium                                                     1    0.500000
# Calypso                                                     2    0.666667
# TA428                                                       2    0.833333
# Gelsemium                                                   2    0.666667
# Stone Panda, APT 10, menuPass                               3    1.166667
# Silence, Contract Crew                                      1    0.500000
# Donot Team                                                  1    0.500000
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...          2    0.833333
# Tonto Team, HartBeat, Karma Panda                           2    0.833333
# APT 42                                                      1    0.500000
# Desert Falcons                                              2    0.666667
# IronHusky                                                   1    0.333333
# Mikroceen                                                   1    0.333333
# InvisiMole                                                  1    0.500000
# APT 19, Deep Panda, C0d0so0                                 1    0.500000
# PKPLUG                                                      1    0.333333
# Lotus Blossom, Spring Dragon, Thrip                         1    0.500000
# Inception Framework, Cloud Atlas                            1    0.500000
# DarkHotel                                                   2    0.666667
# RedAlpha                                                    1    0.333333
# El Machete                                                  1    0.500000
# Naikon, Lotus Panda                                         1    0.500000
# RedFoxtrot                                                  1    0.333333
# Patchwork, Dropping Elephant                                1    0.333333
# Bronze Butler, Tick, RedBaldNight, Stalker Panda            1    0.333333
# Winnti Group, Blackfly, Wicked Panda                        1    0.333333
# TaskMasters                                                 1    0.333333
#
#                                                       weight
# etda_name
# Wizard Spider, Gold Blackburn                       1.883333
# Operation Ghostwriter                               0.738095
# Gamaredon Group                                     0.681818
# Mummy Spider, TA542                                 0.666667
# SaintBear, Lorec53                                  0.666667
# Lazarus Group, Hidden Cobra, Labyrinth Chollima     0.656863
# Doppel Spider                                       0.466667
# APT 29, Cozy Bear, The Dukes                        0.447917
# Magic Hound, APT 35, Cobalt Illusion, Charming ...  0.430556
# Reaper, APT 37, Ricochet Chollima, ScarCruft        0.430556
# Kimsuky, Velvet Chollima                            0.319444
# Mustang Panda, Bronze President                     0.305556
# APT 41                                              0.263889
# Curious Gorge                                       0.250000
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten    0.238095
# Sandworm Team, Iron Viking, Voodoo Bear             0.233333
# TA2101, Maze Team                                   0.233333
# RedDelta                                            0.208333
# OilRig, APT 34, Helix Kitten, Chrysene              0.183333
# Transparent Tribe, APT 36                           0.181818
# Moses Staff                                         0.166667
# Indrik Spider                                       0.156863
# Emissary Panda, APT 27, LuckyMouse, Bronze Union    0.154762
# Sofacy, APT 28, Fancy Bear, Sednit                  0.150000
# Blind Eagle                                         0.138889
# Evilnum                                             0.138889
# Bitter                                              0.121212
# Molerats, Extreme Jackal, Gaza Cybergang            0.111111
# SideWinder, Rattlesnake                             0.111111
# Aggah                                               0.111111
# Turla, Waterbug, Venomous Bear                      0.107143
# FIN7                                                0.106061
# Gallium                                             0.083333
# Calypso                                             0.083333
# TA428                                               0.075758
# Gelsemium                                           0.066667
# Stone Panda, APT 10, menuPass                       0.064815
# Silence, Contract Crew                              0.062500
# Donot Team                                          0.062500
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...  0.059524
# Tonto Team, HartBeat, Karma Panda                   0.055556
# APT 42                                              0.055556
# Desert Falcons                                      0.051282
# IronHusky                                           0.047619
# Mikroceen                                           0.047619
# InvisiMole                                          0.045455
# APT 19, Deep Panda, C0d0so0                         0.045455
# PKPLUG                                              0.041667
# Lotus Blossom, Spring Dragon, Thrip                 0.041667
# Inception Framework, Cloud Atlas                    0.041667
# DarkHotel                                           0.039216
# RedAlpha                                            0.037037
# El Machete                                          0.035714
# Naikon, Lotus Panda                                 0.035714
# RedFoxtrot                                          0.033333
# Patchwork, Dropping Elephant                        0.030303
# Bronze Butler, Tick, RedBaldNight, Stalker Panda    0.023810
# Winnti Group, Blackfly, Wicked Panda                0.023810
# TaskMasters                                         0.023810

# %%
def normalize(df):
    return (df-df.min())/(df.max()-df.min())

actors_filtered['actor_weight'] = normalize(actors_filtered['weight'])

actors_filtered.sort_values(by='actor_weight',ascending=False)

actors_ranked = actors_filtered[['actor_weight','mitre_attack_ttps']]
unique_ttps = to_1D(actors_ranked['mitre_attack_ttps']).value_counts()

print('Number of actors:',actors_ranked.index.size)
print('Number of TTPs:\t', unique_ttps.index.size)
# Out:
# Number of actors: 59
# Number of TTPs:	 321

# %%
actor_weights = actors_ranked['actor_weight']
actor_weights.nlargest(5).plot(kind='barh',xlabel='Actor Name', title="Top 5 actors targeting {} sector based on operations between {} and {} (normalized)".format(SECTOR,YEAR-INTERVAL,YEAR))
# Out:
# <AxesSubplot:title={'center':'Top 5 actors targeting Government sector based on operations between 2021 and 2023 (normalized)'}, ylabel='Actor Name'>

# %%
actors_ranked
# Out:
#                                                     actor_weight  \
# etda_name
# Wizard Spider, Gold Blackburn                           1.000000
# Lazarus Group, Hidden Cobra, Labyrinth Chollima         0.340438
# APT 29, Cozy Bear, The Dukes                            0.228073
# Gamaredon Group                                         0.353859
# Mummy Spider, TA542                                     0.345711
# Magic Hound, APT 35, Cobalt Illusion, Charming ...      0.218737
# Reaper, APT 37, Ricochet Chollima, ScarCruft            0.218737
# Operation Ghostwriter                                   0.384123
# APT 41                                                  0.129108
# Indrik Spider                                           0.071552
# Kimsuky, Velvet Chollima                                0.158984
# Mustang Panda, Bronze President                         0.151515
# Sofacy, APT 28, Fancy Bear, Sednit                      0.067862
# Turla, Waterbug, Venomous Bear                          0.044814
# Doppel Spider                                           0.238156
# Sandworm Team, Iron Viking, Voodoo Bear                 0.112676
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten        0.115237
# Emissary Panda, APT 27, LuckyMouse, Bronze Union        0.070423
# Transparent Tribe, APT 36                               0.084973
# Molerats, Extreme Jackal, Gaza Cybergang                0.046948
# OilRig, APT 34, Helix Kitten, Chrysene                  0.085787
# SaintBear, Lorec53                                      0.345711
# SideWinder, Rattlesnake                                 0.046948
# Stone Panda, APT 10, menuPass                           0.022052
# TA2101, Maze Team                                       0.112676
# FIN7                                                    0.044232
# Bitter                                                  0.052380
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...      0.019206
# RedDelta                                                0.099232
# Calypso                                                 0.032010
# DarkHotel                                               0.008285
# Desert Falcons                                          0.014774
# Evilnum                                                 0.061886
# Tonto Team, HartBeat, Karma Panda                       0.017072
# Gelsemium                                               0.023047
# TA428                                                   0.027936
# Aggah                                                   0.046948
# Blind Eagle                                             0.061886
# Silence, Contract Crew                                  0.020807
# TaskMasters                                             0.000000
# Winnti Group, Blackfly, Wicked Panda                    0.000000
# RedFoxtrot                                              0.005122
# Moses Staff                                             0.076825
# RedAlpha                                                0.007113
# Patchwork, Dropping Elephant                            0.003492
# PKPLUG                                                  0.009603
# Naikon, Lotus Panda                                     0.006402
# Bronze Butler, Tick, RedBaldNight, Stalker Panda        0.000000
# Mikroceen                                               0.012804
# APT 42                                                  0.017072
# Lotus Blossom, Spring Dragon, Thrip                     0.009603
# IronHusky                                               0.012804
# InvisiMole                                              0.011640
# Inception Framework, Cloud Atlas                        0.009603
# Gallium                                                 0.032010
# El Machete                                              0.006402
# Donot Team                                              0.020807
# Curious Gorge                                           0.121639
# APT 19, Deep Panda, C0d0so0                             0.011640
#
#                                                                                     mitre_attack_ttps
# etda_name
# Wizard Spider, Gold Blackburn                       [T1070.004, T1557.001, T1543.003, T1003.002, T...
# Lazarus Group, Hidden Cobra, Labyrinth Chollima     [T1573.001, T1070.003, T1588.002, T1560.002, T...
# APT 29, Cozy Bear, The Dukes                        [T1078.004, T1001.002, T1087, T1562.004, T1560...
# Gamaredon Group                                     [T1559.001, T1036.005, T1218.011, T1608.001, T...
# Mummy Spider, TA542                                                                   [Not Available]
# Magic Hound, APT 35, Cobalt Illusion, Charming ...  [T1105, T1053.005, T1059.001, T1586.002, T1564...
# Reaper, APT 37, Ricochet Chollima, ScarCruft        [T1055, T1053.005, T1189, T1559.002, T1566.001...
# Operation Ghostwriter                                                                 [Not Available]
# APT 41                                              [T1203, T1574.002, T1078, T1104, T1005, T1016,...
# Indrik Spider                                       [T1486, T1003.001, T1059.001, T1204.002, T1059...
# Kimsuky, Velvet Chollima                            [T1059.001, T1594, T1136.001, T1560.001, T1562...
# Mustang Panda, Bronze President                     [T1566.002, T1573.001, T1003.003, T1546.003, T...
# Sofacy, APT 28, Fancy Bear, Sednit                  [T1036.005, T1218.011, T1566.001, T1211, T1498...
# Turla, Waterbug, Venomous Bear                      [T1112, T1005, T1102, T1025, T1105, T1102.002,...
# Doppel Spider                                                                         [Not Available]
# Sandworm Team, Iron Viking, Voodoo Bear             [T1491.002, T1070.004, T1027, T1594, T1140, T1...
# MuddyWater, Seedworm, TEMP.Zagros, Static Kitten    [T1059.007, T1057, T1087.002, T1555, T1105, T1...
# Emissary Panda, APT 27, LuckyMouse, Bronze Union    [T1190, T1574.001, T1059.001, T1133, T1547.001...
# Transparent Tribe, APT 36                           [T1583.001, T1189, T1059.005, T1036.005, T1584...
# Molerats, Extreme Jackal, Gaza Cybergang            [T1547.001, T1027, T1555.003, T1057, T1553.002...
# OilRig, APT 34, Helix Kitten, Chrysene              [T1048.003, T1059.001, T1033, T1003.004, T1082...
# SaintBear, Lorec53                                  [T1218.002, T1566.002, T1059.003, T1059.007, T...
# SideWinder, Rattlesnake                             [T1204.001, T1059.001, T1016, T1203, T1218.005...
# Stone Panda, APT 10, menuPass                       [T1574.001, T1090.002, T1039, T1210, T1199, T1...
# TA2101, Maze Team                                                                     [Not Available]
# FIN7                                                [T1078, T1102.002, T1047, T1583.001, T1486, T1...
# Bitter                                              [T1027, T1053.005, T1071.001, T1588.002, T1204...
# Ke3chang, Vixen Panda, APT 15, GREF, Playful Dr...  [T1007, T1071.004, T1082, T1560.001, T1059, T1...
# RedDelta                                                                              [Not Available]
# Calypso                                                                               [Not Available]
# DarkHotel                                           [T1083, T1547.001, T1140, T1080, T1497.002, T1...
# Desert Falcons                                                                        [Not Available]
# Evilnum                                             [T1566.002, T1574.001, T1539, T1555, T1059.007...
# Tonto Team, HartBeat, Karma Panda                   [T1135, T1068, T1003, T1203, T1204.002, T1210,...
# Gelsemium                                                                                          []
# TA428                                                                                 [Not Available]
# Aggah                                                                                 [Not Available]
# Blind Eagle                                         [T1588.002, T1059.005, T1027, T1204.002, T1036...
# Silence, Contract Crew                              [T1055, T1059.007, T1218.001, T1112, T1036.005...
# TaskMasters                                                                           [Not Available]
# Winnti Group, Blackfly, Wicked Panda                [T1083, T1583.001, T1057, T1553.002, T1105, T1...
# RedFoxtrot                                                                            [Not Available]
# Moses Staff                                         [T1105, T1587.001, T1087.001, T1505.003, T1588...
# RedAlpha                                                                              [Not Available]
# Patchwork, Dropping Elephant                        [T1203, T1033, T1553.002, T1566.001, T1021.001...
# PKPLUG                                                                                [Not Available]
# Naikon, Lotus Panda                                 [T1046, T1547.001, T1137.006, T1518.001, T1047...
# Bronze Butler, Tick, RedBaldNight, Stalker Panda    [T1059.003, T1102.001, T1518, T1070.004, T1083...
# Mikroceen                                                                             [Not Available]
# APT 42                                                                                [Not Available]
# Lotus Blossom, Spring Dragon, Thrip                          [T1059.001, T1588.002, T1219, T1048.003]
# IronHusky                                                                             [Not Available]
# InvisiMole                                                                            [Not Available]
# Inception Framework, Cloud Atlas                    [T1203, T1083, T1059.005, T1218.010, T1547.001...
# Gallium                                             [T1553.002, T1047, T1041, T1049, T1074.001, T1...
# El Machete                                          [T1036.005, T1032, T1059.003, T1204.002, T1218...
# Donot Team                                                                            [Not Available]
# Curious Gorge                                                                         [Not Available]
# APT 19, Deep Panda, C0d0so0                         [T1140, T1566.001, T1033, T1574.002, T1071.001...

# %% [markdown]
# #### Observations
# Since the Government sector is the most represented in the ETDA dataset, this one is chosen for the tests. 13 of the actors from the reports target this sector. APT 29 is mentioned the most across reports. This is due to their notorious SolarWinds attack in 2020, which is mentioned often. In 2021 they also launched a big spear-phishing campaign. This actor is followed by Wizard Spider, a ransomware actor that is very active.
#
# It is mainly these two actors that exceed the others in terms of how often they are mentioned. The other mentioned actors have a weigth just below 1.0.

# %% [markdown]
# ### 2.2. Rank TTPs
# #### 2.3.1 Explode dataframe per TTP
# Explode the dataframe per TTP. Now a weighting calculation can be done per TTP, based on the information provided. Information includes the actor results (and kill chain phase).
#
# For now: the actor weights are summed per TTP to obtain a ranking per TTP.

# %%
actors_ranked['number_of_actors'] = 1
actors_ttp_exploded = actors_ranked.explode('mitre_attack_ttps')
# Out:
# C:\Users\a.winters\AppData\Local\Temp\ipykernel_14632\823944124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors_ranked['number_of_actors'] = 1

# %% [markdown]
# #### 2.3.2. Group by TTP and sum actor weights
# Sum the actor weights.

# %%
actors_ttp_summed = actors_ttp_exploded.reset_index(drop=True)
ttps_ranked = actors_ttp_summed.groupby('mitre_attack_ttps').sum()
print(ttps_ranked.sort_values(by='actor_weight',ascending=False))
# Out:
#                    actor_weight  number_of_actors
# mitre_attack_ttps
# T1027                  4.183248                31
# T1204.002              3.982713                31
# T1059.003              3.869999                26
# T1566.001              3.821532                30
# T1059.001              3.759184                28
# ...                         ...               ...
# T1029                  0.008285                 1
# T1497                  0.008285                 1
# T1137.006              0.006402                 1
# T1032                  0.006402                 1
# T1587.002              0.003492                 1
#
# [321 rows x 2 columns]

# %% [markdown]
# #### 2.3.3 Enrich TTP information
# Information from the ATT&CK data is used via the attackcti package.

# %%
from attackcti import attack_client
from pandas import json_normalize
import sys

mitre_columns = ['technique_id','technique','kill_chain_phases','id','tactic','technique_detection','impact_type']

def get_attck_dataframe(matrix = 'enterprise'):
    if  (matrix.lower() == 'enterprise'):
        # Instantiating attack_client class
        lift = attack_client()
        # Getting techniques for windows platform - enterprise matrix
        attck = lift.get_enterprise_techniques(stix_format = False)
        # Generating a dataframe with information collected
        attck = json_normalize(attck)
        return attck
    else:
        sys.exit('ERROR: Only Enterprise available!!')

attck = get_attck_dataframe()
attck = attck[mitre_columns]

ttps_enriched = pd.merge(ttps_ranked,attck,how='left',left_index=True,right_on='technique_id')
ttps_enriched.index = ttps_ranked.index
ttps_enriched['technique_name_id'] = ttps_enriched['technique'] + " (" + ttps_enriched['technique_id'] + ")"
# Out:
# [taxii2client.v20] [WARNING ] [2023-05-26 14:51:05,225] TAXII Server Response did not include 'Content-Range' header - results could be incomplete.
# [taxii2client.v20] [WARNING ] [2023-05-26 14:51:05,269] TAXII Server Response with different amount of objects! Setting per_request=750

# %% [markdown]
# #### 2.3.4. Calculate weights

# %%
ttps_enriched['ttp_weight'] = normalize(ttps_enriched['actor_weight'])
ttps_enriched = ttps_enriched.drop(['actor_weight'],axis=1)

# %% [markdown]
# #### Statistics

# %%
ttps_enriched.nlargest(10,columns='ttp_weight').plot.barh(y='ttp_weight',x='technique_name_id',xlabel="TTP Name and ATT&CK ID" ,title="Top 10 techniques for actors targeting {} sector".format(SECTOR))

# ttps_enriched.plot.hist(column="number_of_actors",bins=10, title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR))
ttps_enriched = ttps_enriched.drop(['number_of_actors'],axis=1)

# %% [markdown]
# Only take the top percentage of the TTPs

# %%
PERCENTAGE = 1

def take_percentage(percentage,df):
    top_percent = int(len(df) * PERCENTAGE)
    print("Taking {}%; {} entries".format(percentage*100,top_percent))
    return df.nlargest(top_percent,columns="ttp_weight")

def take_threshold(threshold, df):
    return df.loc[df['ttp_weight']>threshold]


ttps_enriched = take_percentage(PERCENTAGE,ttps_enriched)
# ttps_enriched = take_threshold(TTP_THRESHOLD,ttps_enriched)
# Out:
# Taking 100%; 321 entries

# %% [markdown]
# #### Observations
# Within the tested Government sector, the top 10 techniques used are shown above.
# The top technique is '[Obfuscated Files or Information](https://attack.mitre.org/techniques/T1027/)', where adversaries obfuscate the contents of an executable or file by encrypting, encoding, compressing or otherwise obscuring them on the system or in transit. This is common behavior to evade defenses.
#
# The second technique is '[Tool]'(https://attack.mitre.org/techniques/T1588/002/), is described as "Adversaries may buy, steal or download software tools that can be used during targeting." This is a very generic technique, since the use of the use of tools is common among hackers and there exists a wide variety of tools, hence why it is listed in such a high position.

# %% [markdown]
# ## 3. Control prioritization

# %% [markdown]
# ### 3.1 Control Mapping
# Source of the mapping: [Security Control Framework Mappings to ATT&CK](https://github.com/center-for-threat-informed-defense/attack-control-framework-mappings).
#
# This maps controls from NIST 800-53 to MITRE ATT&CK. The following versions are considered:
# - MITRE ATT&CK v10.1
# - NIST 800-53 Revision 5

# %%
# Load ATT&CK to NIST 800-53 mapping
def get_nist_attck_mapping():
    nist_attck_mapping = pd.read_excel("data/mappings/nist800-53-r5-mappings.xlsx")
    nist_attck_mapping = nist_attck_mapping.drop(["Mapping Type","Technique Name"],axis=1)
    return nist_attck_mapping

def get_cis_attck_mapping():
    return None

def get_iso_attck_mapping():
    iso_attck_mapping = pd.read_excel("data/mappings/ISO_27001_2022_ATTCKv82.xlsx")
    return iso_attck_mapping

# %% [markdown]
# Merge the TTPs with the controls. Only keep the TTPs that have a weight above a certain threshold. This threshold will be experimented with. The following values are considered:
# - All TTPs
# - threshold > 0.25
# - threshold > 0.5
# - threshold > 0.7
# - threshold > 0.9

# %%
ttp_control_map = get_iso_attck_mapping()

ttp_control_merge = ttp_control_map.merge(ttps_enriched, left_on="Technique ID", right_on="technique_id",how="inner")
ttp_control_merge.sort_values(by='ttp_weight',inplace=True,ascending=False)
print("Number of TTPS:",ttp_control_merge['Technique ID'].value_counts().index.size)
print("Number of controls:",ttp_control_merge['Control ID'].value_counts().index.size)
ttp_control_merge
# Out:
# Number of TTPS: 202
# Number of controls: 42
#       Control ID Technique ID                             Control Name  \
# 562         8.16        T1027                    Monitoring activities
# 561         8.10        T1027                    User endpoint devices
# 560         8.70        T1027               Protection against malware
# 559         8.80        T1027  Management of technical vulnerabilities
# 1250        8.70    T1204.002               Protection against malware
# ...          ...          ...                                      ...
# 827         8.30    T1558.001           Information access restriction
# 829         8.50    T1558.001                    Secure authentication
# 688         8.16        T1029                    Monitoring activities
# 687         8.21        T1029             Security of network services
# 686         8.80        T1029  Management of technical vulnerabilities
#
#      technique_id                        technique  \
# 562         T1027  Obfuscated Files or Information
# 561         T1027  Obfuscated Files or Information
# 560         T1027  Obfuscated Files or Information
# 559         T1027  Obfuscated Files or Information
# 1250    T1204.002                   Malicious File
# ...           ...                              ...
# 827     T1558.001                    Golden Ticket
# 829     T1558.001                    Golden Ticket
# 688         T1029               Scheduled Transfer
# 687         T1029               Scheduled Transfer
# 686         T1029               Scheduled Transfer
#
#                                       kill_chain_phases  \
# 562   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 561   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 560   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 559   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 1250  [{'kill_chain_name': 'mitre-attack', 'phase_na...
# ...                                                 ...
# 827   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 829   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 688   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 687   [{'kill_chain_name': 'mitre-attack', 'phase_na...
# 686   [{'kill_chain_name': 'mitre-attack', 'phase_na...
#
#                                                      id               tactic  \
# 562   attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...    [defense-evasion]
# 561   attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...    [defense-evasion]
# 560   attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...    [defense-evasion]
# 559   attack-pattern--b3d682b6-98f2-4fb0-aa3b-b4df00...    [defense-evasion]
# 1250  attack-pattern--232b7f21-adf9-4b42-b936-b9d6f7...          [execution]
# ...                                                 ...                  ...
# 827   attack-pattern--768dce68-8d0d-477a-b01d-0eea98...  [credential-access]
# 829   attack-pattern--768dce68-8d0d-477a-b01d-0eea98...  [credential-access]
# 688   attack-pattern--4eeaf8a9-c86b-4954-a663-9555fb...       [exfiltration]
# 687   attack-pattern--4eeaf8a9-c86b-4954-a663-9555fb...       [exfiltration]
# 686   attack-pattern--4eeaf8a9-c86b-4954-a663-9555fb...       [exfiltration]
#
#                                     technique_detection impact_type  \
# 562   Detection of file obfuscation is difficult unl...         NaN
# 561   Detection of file obfuscation is difficult unl...         NaN
# 560   Detection of file obfuscation is difficult unl...         NaN
# 559   Detection of file obfuscation is difficult unl...         NaN
# 1250  Monitor the execution of and command-line argu...         NaN
# ...                                                 ...         ...
# 827   Monitor for anomalous Kerberos activity, such ...         NaN
# 829   Monitor for anomalous Kerberos activity, such ...         NaN
# 688   Monitor process file access patterns and netwo...         NaN
# 687   Monitor process file access patterns and netwo...         NaN
# 686   Monitor process file access patterns and netwo...         NaN
#
#                             technique_name_id  ttp_weight
# 562   Obfuscated Files or Information (T1027)    1.000000
# 561   Obfuscated Files or Information (T1027)    1.000000
# 560   Obfuscated Files or Information (T1027)    1.000000
# 559   Obfuscated Files or Information (T1027)    1.000000
# 1250               Malicious File (T1204.002)    0.952022
# ...                                       ...         ...
# 827                 Golden Ticket (T1558.001)    0.003760
# 829                 Golden Ticket (T1558.001)    0.003760
# 688                Scheduled Transfer (T1029)    0.001147
# 687                Scheduled Transfer (T1029)    0.001147
# 686                Scheduled Transfer (T1029)    0.001147
#
# [1675 rows x 12 columns]

# %% [markdown]
# Get TTPs incl number of controls that mitigate them

# %%
ttp_control_merge[['Technique ID','ttp_weight']].drop_duplicates().plot(kind='hist',bins=30,title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR))
# ttp_control_merge['ttp_weight'].plot(kind='hist',bins=30,title="Distribution of TTP weights for actors targeting {} sector".format(SECTOR),xlabel="TTP weights")
# Out:
# <AxesSubplot:title={'center':'Distribution of TTP weights for actors targeting Government sector'}, ylabel='Frequency'>

# %% [markdown]
# **Observations**
#
# The TTP weights are a normalised summation of the actor weights. This means, the higher the TTP weight, the more (high weighted) actors share this TTP.
# We can see that the distribution of TTP weights is a right-skewed distribution. This is expected, since this means that the number of TTPs that are shared by these actors is

# %%
# ttp_control_merge[['Control ID','Control Name']].value_counts().nlargest(10).plot(kind='barh',title="Number of selected TTPs mitigated per control")

ttp_control_ranked = ttp_control_merge.groupby(['Control ID','Control Name']).sum()
ttp_control_ranked.sort_values(by='ttp_weight',ascending=False)

# ttp_control_ranked.nlargest(10,columns='ttp_weight').plot(kind='barh',title="Top controls by number of mitigated TTPs. No TTP threshold")
ttp_control_ranked.nlargest(10,columns='ttp_weight').plot(kind='barh',title="Top controls by number of mitigated TTPs. Top {}% of TTPS".format(PERCENTAGE*100))
# Out:
# <AxesSubplot:title={'center':'Top controls by number of mitigated TTPs. Top 100% of TTPS'}, ylabel='Control ID,Control Name'>

# %% [markdown]
# #### Observations
# There are some controls that map to a lot of TTPs. For the complete results for the ‘Government’ sector, there are 215 TTPs and 106 controls. Merging the two gives a resulting set of 2545 mappings. Since there is no measure of control effectiveness to a TTP in this data, they are sorted based on the TTPs they control and their respective weights.
#
# There are two ways to approach the control mapping, either a generic approach or a targeted approach.
# - Targeted: Take the most prominent TTPs, those with the highest weights, and display the controls for this.
# - Generic: Take the complete, or near-complete, set of TTPs used by the actors. Rank the controls based on the number of TTPs they control and their respective weights. The downside of this is that controls that map to a large number of TTPs will probably always end up on top. This means that the initial TTP ranking matters less.
#
# When simply counting the number of TTPs that a control covers, only the general ones come to the top. Even if the TTP weights are considered. One possibility to solve this, is to only take the top x% of TTPs into consideration.
